# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../data/stats.csv')

# %%
data.head()
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 0  Manchester United  28.0     5.0   83.0            60.0             1.0
# 1            Chelsea  24.0     3.0   64.0            62.0             4.0
# 2          Liverpool  20.0    10.0   57.0            44.0             0.0
# 3            Arsenal  19.0     8.0   63.0            59.0             3.0
# 4  Tottenham Hotspur  17.0    12.0   57.0            48.0             3.0
#
#    total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0              698.0                 256.0          21.0         12.0  ...
# 1              636.0                 216.0          14.0         16.0  ...
# 2              668.0                 214.0          15.0          8.0  ...
# 3              638.0                 226.0          19.0         10.0  ...
# 4              520.0                 184.0           6.0          5.0  ...
#
# ...

# %%
df = data.loc[:, ['team', 'wins', 'losses', 'season']]
df['draws'] = 38 - df['wins'] - df['losses']

# %%
df['points'] = df['wins'] * 3 + df['draws'] * 1
df['points'] = df['points'].astype(int)

# %%
desired_columns_order = ['team', 'wins', 'losses', 'draws', 'points', 'season']
df = df[desired_columns_order]

# %%
df.head()
# Out:
#                 team  wins  losses  draws  points     season
# 0  Manchester United  28.0     5.0    5.0      89  2006-2007
# 1            Chelsea  24.0     3.0   11.0      83  2006-2007
# 2          Liverpool  20.0    10.0    8.0      68  2006-2007
# 3            Arsenal  19.0     8.0   11.0      68  2006-2007
# 4  Tottenham Hotspur  17.0    12.0    9.0      60  2006-2007

# %%
for season, group in df.groupby("season"):
    season_csv_filename = f'points_season_{season}.csv'
    group.to_csv("../data/" + season_csv_filename, index=False)
    print(f"Saved {season_csv_filename}")
# Out:
# Saved points_season_2006-2007.csv
# Saved points_season_2007-2008.csv
# Saved points_season_2008-2009.csv
# Saved points_season_2009-2010.csv
# Saved points_season_2010-2011.csv
# Saved points_season_2011-2012.csv
# Saved points_season_2012-2013.csv
# Saved points_season_2013-2014.csv
# Saved points_season_2014-2015.csv
# Saved points_season_2015-2016.csv
# Saved points_season_2016-2017.csv
# Saved points_season_2017-2018.csv
