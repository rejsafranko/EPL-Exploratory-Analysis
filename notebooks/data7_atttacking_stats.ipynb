# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('../data/stats.csv')
data.head()
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 0  Manchester United  28.0     5.0   83.0            60.0             1.0
# 1            Chelsea  24.0     3.0   64.0            62.0             4.0
# 2          Liverpool  20.0    10.0   57.0            44.0             0.0
# 3            Arsenal  19.0     8.0   63.0            59.0             3.0
# 4  Tottenham Hotspur  17.0    12.0   57.0            48.0             3.0
#
#    total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0              698.0                 256.0          21.0         12.0  ...
# 1              636.0                 216.0          14.0         16.0  ...
# 2              668.0                 214.0          15.0          8.0  ...
# 3              638.0                 226.0          19.0         10.0  ...
# 4              520.0                 184.0           6.0          5.0  ...
#
# ...

# %%
data.columns
# Out:
# Index(['team', 'wins', 'losses', 'goals', 'total_yel_card', 'total_red_card',
#        'total_scoring_att', 'ontarget_scoring_att', 'hit_woodwork',
#        'att_hd_goal', 'att_pen_goal', 'att_freekick_goal', 'att_ibox_goal',
#        'att_obox_goal', 'goal_fastbreak', 'total_offside', 'clean_sheet',
#        'goals_conceded', 'saves', 'outfielder_block', 'interception',
#        'total_tackle', 'last_man_tackle', 'total_clearance', 'head_clearance',
#        'own_goals', 'penalty_conceded', 'pen_goals_conceded', 'total_pass',
#        'total_through_ball', 'total_long_balls', 'backward_pass',
#        'total_cross', 'corner_taken', 'touches', 'big_chance_missed',
#        'clearance_off_line', 'dispossessed', 'penalty_save',
#        'total_high_claim', 'punches', 'season'],
#       dtype='object')

# %%
filtered_df = data.loc[:, ['team', 'ontarget_scoring_att', 'att_hd_goal', 'att_pen_goal',  'att_freekick_goal', 
                           'att_ibox_goal', 'att_obox_goal', 'goal_fastbreak', 'total_offside', 'season']]

# %%
filtered_df.head()
# Out:
#                 team  ontarget_scoring_att  att_hd_goal  att_pen_goal  \
# 0  Manchester United                 256.0         12.0           5.0
# 1            Chelsea                 216.0         16.0           3.0
# 2          Liverpool                 214.0          8.0           6.0
# 3            Arsenal                 226.0         10.0          10.0
# 4  Tottenham Hotspur                 184.0          5.0           6.0
#
#    att_freekick_goal  att_ibox_goal  att_obox_goal  goal_fastbreak  \
# 0                1.0           72.0           11.0             9.0
# 1                6.0           41.0           23.0             6.0
# 2                1.0           46.0           11.0             3.0
# 3                3.0           53.0           10.0             7.0
# 4                2.0           44.0           13.0             9.0
#
#    total_offside     season
# 0           80.0  2006-2007
# 1          127.0  2006-2007
# 2          120.0  2006-2007
# ...

# %%
for season, group in filtered_df.groupby("season"):
    season_csv_filename = f'attacking_stats_{season}.csv'
    group.to_csv("../data/" + season_csv_filename, index=False)
    print(f"Saved {season_csv_filename}")
# Out:
# Saved attacking_stats_2006-2007.csv
# Saved attacking_stats_2007-2008.csv
# Saved attacking_stats_2008-2009.csv
# Saved attacking_stats_2009-2010.csv
# Saved attacking_stats_2010-2011.csv
# Saved attacking_stats_2011-2012.csv
# Saved attacking_stats_2012-2013.csv
# Saved attacking_stats_2013-2014.csv
# Saved attacking_stats_2014-2015.csv
# Saved attacking_stats_2015-2016.csv
# Saved attacking_stats_2016-2017.csv
# Saved attacking_stats_2017-2018.csv
